# %%
# variable int , float , string, boolean ,complex , list , tuple,dict,set,class
a=12 #var opt value # dynamically typed language """ """
print(a)
# Out:
# 12

# %%
user=input("Enter your name : ")
print("Hello ",user)
print(type(user))
# Out:
# Hello  jatin pathak
# <class 'str'>

# %%
user_num=int(input("Enter a number : "))
print("hello",user_num)
print(type(user_num))
# Out:
# hello 98
# <class 'int'>

# %%
a= 10.56 # float number
print(a)
b= 2+ 3j # complex number
print(b)
c= True # boolean
print(c)
d= "Hello World", # string
print(d)
e='a'  # string
print(e)
f="""This is a multi-line string""" #·multi-line string
print(f)
# Out:
# 10.56
# (2+3j)
# True
# ('Hello World',)
# a
# This is a multi-line string

# %%
a=10,2,3,4,5 # tuple
print(type(a)) #tuple
# Out:
# <class 'tuple'>

# %%
a=() # empty tuple
b=[] # empty list
c={k: v} #  dict
d={} #set
